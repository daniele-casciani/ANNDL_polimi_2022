# %%
# mount gdrive

from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/ANDL/Homework_1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/ANDL/Homework_1

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.optimizers import adam_v2

import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow.keras as tfk
import random
import os
import tensorflow as tf
from PIL import Image

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
# Dataset folders 
dataset_dir = 'atMost700'
training_dir = os.path.join(dataset_dir, 'train')
validation_dir = os.path.join(dataset_dir, 'val')
test_dir = os.path.join(dataset_dir, 'test')

labels = ['Species1','Species2','Species3','Species4','Species5','Species6','Species7','Species8',]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
category_names = sorted(os.listdir(training_dir))
nb_categories = len(category_names)
img_pr_cat = []
for category in category_names:
    folder = training_dir + '/' + category
    img_pr_cat.append(len(os.listdir(folder)))
sns.barplot(y=category_names, x=img_pr_cat).set_title("Number of training images per category:")
# Out:
# Text(0.5, 1.0, 'Number of training images per category:')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import array_to_img, img_to_array, load_img

# Create an instance of ImageDataGenerator with Data Augmentation
aug_train_data_gen = ImageDataGenerator(#rotation_range=180,
                                        height_shift_range=5,
                                        width_shift_range=5,
                                        #zoom_range=0.5,
                                        horizontal_flip=True,
                                        vertical_flip=True, 
                                        #fill_mode='nearest',
                                        preprocessing_function = preprocess_input,
                                        # rescale=1/255. not on vgg16
                                        ) 
valid_data_gen = ImageDataGenerator(#rescale=1/255.,
                                    preprocessing_function = preprocess_input)
test_data_gen = ImageDataGenerator(#rescale=1/255.,
                                   preprocessing_function = preprocess_input)

# %%
# Obtain a data generator with the 'ImageDataGenerator.flow_from_directory' method
aug_train_gen = aug_train_data_gen.flow_from_directory(directory=training_dir,
                                                       target_size=(96,96),
                                                       color_mode='rgb',
                                                       classes=None, # can be set to labels
                                                       class_mode='categorical',
                                                       batch_size=32,
                                                       shuffle=True,
                                                       seed=seed)

valid_gen = valid_data_gen.flow_from_directory(directory=validation_dir,
                                               target_size=(96,96),
                                               color_mode='rgb',
                                               classes=None, # can be set to labels
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=True,
                                               seed=seed)
test_gen = test_data_gen.flow_from_directory(directory=test_dir,
                                             target_size=(96,96),
                                             color_mode='rgb',
                                             classes=None, # can be set to labels
                                             class_mode='categorical',
                                             batch_size=32,
                                             shuffle=False,
                                             seed=seed)
# Out:
# Found 5600 images belonging to 8 classes.
# Found 527 images belonging to 8 classes.
# Found 361 images belonging to 8 classes.

# %%
def get_next_batch(generator):
  batch = next(generator)

  image = batch[0]
  target = batch[1]

  print("(Input) image shape:", image.shape)
  print("Target shape:",target.shape)

  # Visualize only the first sample
  image = image[0]
  target = target[0]
  target_idx = np.argmax(target)
  print()
  print("Categorical label:", target)
  print("Label:", target_idx)
  print("Class name:", labels[target_idx])
  fig = plt.figure(figsize=(6, 4))
  plt.imshow(np.uint8(image))

  return batch

# %%
# Get a sample from dataset and show info
_ = get_next_batch(aug_train_gen)
# Out:
# (Input) image shape: (32, 96, 96, 3)
# Target shape: (32, 8)
#
# Categorical label: [0. 0. 0. 0. 0. 0. 1. 0.]
# Label: 6
# Class name: Species7

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name):

  exps_dir = os.path.join('Vgg19')
  if not os.path.exists(exps_dir):
      os.makedirs(exps_dir)

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=False, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
  callbacks.append(ckpt_callback)

  # Visualize Learning on Tensorboard
  # ---------------------------------
  tb_dir = os.path.join(exp_dir, 'tb_logs')
  if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
      
  # By default shows losses and metrics for both training and validation
  tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, 
                                               profile_batch=0,
                                               histogram_freq=1)  # if > 0 (epochs) shows weights histograms
  callbacks.append(tb_callback)

  # Early Stopping
  # --------------
  es_callback  = tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True)
  callbacks.append(es_callback)

  return callbacks

# %%
# Download and plot the VGG19 model
supernet = tfk.applications.VGG19(
    include_top=False,
    weights="imagenet",
    input_shape=(96,96,3)
)
supernet.summary()
tfk.utils.plot_model(supernet)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
input_shape = (96, 96, 3)
epochs = 200

# %%
import tensorflow.keras.layers as tfkl

# Use the supernet as feature extractor
supernet.trainable = False

inputs = tfk.Input(shape=(96,96,3))
# No resize
#x = tfkl.Resizing(64, 64, interpolation="bicubic")(inputs)
x = supernet(inputs)
x = tfkl.Flatten(name='Flattening')(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
x = tfkl.Dense(
    256, 
    activation='relu',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
output_layer = tfkl.Dense(units=8, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='Output')(x)



# Connect input and output through the Model class
tl_model = tfk.Model(inputs=inputs, outputs=output_layer, name='model')

# Compile the model
tl_model.compile(loss='categorical_crossentropy', optimizer=tfk.optimizers.Adam(), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg19 (Functional)          (None, 3, 3, 512)         20024384
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 21,206,344
# Trainable params: 1,181,960
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
for i, layer in enumerate(tl_model.get_layer('vgg19').layers):
   layer.trainable = False

for i, layer in enumerate(tl_model.get_layer('vgg19').layers):
   print(i, layer.name, layer.trainable)

# %%
# Train the model
tl_callbacks = create_folders_and_callbacks(model_name = 'transfer_learning')

# Train the model
tl_history = tl_model.fit(
    x = aug_train_gen,
    epochs = epochs,
    validation_data = valid_gen,
    callbacks = tl_callbacks,
    #class_weight=class_weight
).history

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(tl_history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(tl_history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
tl_model.save('Vgg19/tl_model_v1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.

# %%
tl_model = tfk.models.load_model('Vgg19/tl_model_v1')
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg19 (Functional)          (None, 3, 3, 512)         20024384
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 21,206,344
# Trainable params: 1,181,960
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
tl_model.get_layer('vgg19').trainable = True
for i, layer in enumerate(tl_model.get_layer('vgg19').layers):
   print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 True
# 1 block1_conv1 True
# 2 block1_conv2 True
# 3 block1_pool True
# 4 block2_conv1 True
# 5 block2_conv2 True
# 6 block2_pool True
# 7 block3_conv1 True
# 8 block3_conv2 True
# 9 block3_conv3 True
# 10 block3_conv4 True
# 11 block3_pool True
# 12 block4_conv1 True
# 13 block4_conv2 True
# 14 block4_conv3 True
# 15 block4_conv4 True
# 16 block4_pool True
# 17 block5_conv1 True
# 18 block5_conv2 True
# 19 block5_conv3 True
# 20 block5_conv4 True
# 21 block5_pool True

# %%
for i, layer in enumerate(tl_model.get_layer('vgg19').layers[:13]):
  layer.trainable=False
for i, layer in enumerate(tl_model.get_layer('vgg19').layers):
   print(i, layer.name, layer.trainable)
tl_model.summary()
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_conv4 False
# 11 block3_pool False
# 12 block4_conv1 False
# 13 block4_conv2 True
# 14 block4_conv3 True
# 15 block4_conv4 True
# 16 block4_pool True
# 17 block5_conv1 True
# 18 block5_conv2 True
# 19 block5_conv3 True
# 20 block5_conv4 True
# 21 block5_pool True
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg19 (Functional)          (None, 3, 3, 512)         20024384
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 21,206,344
# Trainable params: 17,700,616
# Non-trainable params: 3,505,728
# _________________________________________________________________

# %%
tl_model.compile(loss='categorical_crossentropy', optimizer=tfk.optimizers.Adam(1e-5), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
# Fine-tune the model
tl_history = tl_model.fit(
    x = aug_train_gen ,
    batch_size = 32,
    epochs = 200,
    validation_data = valid_gen,
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, verbose=2 , restore_best_weights=True)],
    #class_weight = class_weight
).history
# Out:
# Epoch 1/200
# 175/175 [==============================] - 3498s 20s/step - loss: 0.7165 - accuracy: 0.7448 - precision: 0.8190 - recall: 0.6675 - val_loss: 0.9385 - val_accuracy: 0.6641 - val_precision: 0.7340 - val_recall: 0.5655
# Epoch 2/200
# 175/175 [==============================] - 26s 148ms/step - loss: 0.6289 - accuracy: 0.7759 - precision: 0.8410 - recall: 0.7141 - val_loss: 0.9070 - val_accuracy: 0.7116 - val_precision: 0.7639 - val_recall: 0.6509
# Epoch 3/200
# 175/175 [==============================] - 25s 145ms/step - loss: 0.5524 - accuracy: 0.8014 - precision: 0.8580 - recall: 0.7446 - val_loss: 0.9564 - val_accuracy: 0.6983 - val_precision: 0.7429 - val_recall: 0.6471
# Epoch 4/200
# 175/175 [==============================] - 25s 145ms/step - loss: 0.4894 - accuracy: 0.8254 - precision: 0.8698 - recall: 0.7802 - val_loss: 0.8418 - val_accuracy: 0.7097 - val_precision: 0.7624 - val_recall: 0.6698
# Epoch 5/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.4484 - accuracy: 0.8398 - precision: 0.8815 - recall: 0.7982 - val_loss: 0.8260 - val_accuracy: 0.7249 - val_precision: 0.7652 - val_recall: 0.6926
# Epoch 6/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.4078 - accuracy: 0.8484 - precision: 0.8867 - recall: 0.8109 - val_loss: 0.8051 - val_accuracy: 0.7514 - val_precision: 0.7904 - val_recall: 0.7154
# Epoch 7/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.3925 - accuracy: 0.8675 - precision: 0.8987 - recall: 0.8318 - val_loss: 0.8952 - val_accuracy: 0.7287 - val_precision: 0.7668 - val_recall: 0.6926
# Epoch 8/200
# 175/175 [==============================] - 25s 145ms/step - loss: 0.3526 - accuracy: 0.8721 - precision: 0.9041 - recall: 0.8432 - val_loss: 0.8026 - val_accuracy: 0.7533 - val_precision: 0.7950 - val_recall: 0.7211
# Epoch 9/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.3350 - accuracy: 0.8811 - precision: 0.9080 - recall: 0.8564 - val_loss: 0.8476 - val_accuracy: 0.7362 - val_precision: 0.7718 - val_recall: 0.7059
# Epoch 10/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.3198 - accuracy: 0.8875 - precision: 0.9153 - recall: 0.8586 - val_loss: 0.8215 - val_accuracy: 0.7666 - val_precision: 0.8075 - val_recall: 0.7400
# Epoch 11/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.2931 - accuracy: 0.9009 - precision: 0.9231 - recall: 0.8786 - val_loss: 0.8750 - val_accuracy: 0.7609 - val_precision: 0.7907 - val_recall: 0.7457
# Epoch 12/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.2814 - accuracy: 0.9029 - precision: 0.9290 - recall: 0.8780 - val_loss: 0.8169 - val_accuracy: 0.7666 - val_precision: 0.8004 - val_recall: 0.7457
# Epoch 13/200
# 175/175 [==============================] - 25s 141ms/step - loss: 0.2531 - accuracy: 0.9143 - precision: 0.9339 - recall: 0.8938 - val_loss: 0.8809 - val_accuracy: 0.7609 - val_precision: 0.7903 - val_recall: 0.7438
# Epoch 14/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.2474 - accuracy: 0.9159 - precision: 0.9339 - recall: 0.8979 - val_loss: 0.7985 - val_accuracy: 0.7723 - val_precision: 0.7932 - val_recall: 0.7571
# Epoch 15/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.2208 - accuracy: 0.9250 - precision: 0.9404 - recall: 0.9093 - val_loss: 0.8627 - val_accuracy: 0.7799 - val_precision: 0.8004 - val_recall: 0.7609
# Epoch 16/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.2221 - accuracy: 0.9234 - precision: 0.9397 - recall: 0.9071 - val_loss: 0.9836 - val_accuracy: 0.7552 - val_precision: 0.7927 - val_recall: 0.7400
# Epoch 17/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.2296 - accuracy: 0.9214 - precision: 0.9401 - recall: 0.9057 - val_loss: 0.7403 - val_accuracy: 0.7932 - val_precision: 0.8232 - val_recall: 0.7685
# Epoch 18/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.2139 - accuracy: 0.9248 - precision: 0.9423 - recall: 0.9098 - val_loss: 0.7867 - val_accuracy: 0.8027 - val_precision: 0.8317 - val_recall: 0.7875
# Epoch 19/200
# 175/175 [==============================] - 25s 145ms/step - loss: 0.1962 - accuracy: 0.9330 - precision: 0.9476 - recall: 0.9212 - val_loss: 0.8806 - val_accuracy: 0.7742 - val_precision: 0.8086 - val_recall: 0.7533
# Epoch 20/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.1873 - accuracy: 0.9352 - precision: 0.9462 - recall: 0.9234 - val_loss: 0.8039 - val_accuracy: 0.8027 - val_precision: 0.8162 - val_recall: 0.7837
# Epoch 21/200
# 175/175 [==============================] - 25s 141ms/step - loss: 0.1794 - accuracy: 0.9420 - precision: 0.9562 - recall: 0.9307 - val_loss: 0.8295 - val_accuracy: 0.8102 - val_precision: 0.8274 - val_recall: 0.7913
# Epoch 22/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.1512 - accuracy: 0.9523 - precision: 0.9626 - recall: 0.9420 - val_loss: 0.9438 - val_accuracy: 0.7723 - val_precision: 0.7917 - val_recall: 0.7571
# Epoch 23/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.1407 - accuracy: 0.9516 - precision: 0.9617 - recall: 0.9421 - val_loss: 0.8503 - val_accuracy: 0.8065 - val_precision: 0.8218 - val_recall: 0.7875
# Epoch 24/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.1605 - accuracy: 0.9473 - precision: 0.9578 - recall: 0.9366 - val_loss: 0.8923 - val_accuracy: 0.8008 - val_precision: 0.8238 - val_recall: 0.7894
# Epoch 25/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.1282 - accuracy: 0.9595 - precision: 0.9682 - recall: 0.9520 - val_loss: 0.9940 - val_accuracy: 0.8065 - val_precision: 0.8164 - val_recall: 0.7932
# Epoch 26/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.1249 - accuracy: 0.9555 - precision: 0.9633 - recall: 0.9471 - val_loss: 0.8892 - val_accuracy: 0.8140 - val_precision: 0.8343 - val_recall: 0.8027
# Epoch 27/200
# 175/175 [==============================] - 25s 141ms/step - loss: 0.1100 - accuracy: 0.9650 - precision: 0.9682 - recall: 0.9582 - val_loss: 0.8917 - val_accuracy: 0.8121 - val_precision: 0.8272 - val_recall: 0.8083
# Epoch 28/200
# 175/175 [==============================] - 25s 141ms/step - loss: 0.1096 - accuracy: 0.9652 - precision: 0.9722 - recall: 0.9602 - val_loss: 1.0112 - val_accuracy: 0.8008 - val_precision: 0.8093 - val_recall: 0.7894
# Epoch 29/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.1076 - accuracy: 0.9636 - precision: 0.9701 - recall: 0.9566 - val_loss: 0.9421 - val_accuracy: 0.8178 - val_precision: 0.8337 - val_recall: 0.8083
# Epoch 30/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.0941 - accuracy: 0.9688 - precision: 0.9742 - recall: 0.9623 - val_loss: 1.1470 - val_accuracy: 0.8008 - val_precision: 0.8145 - val_recall: 0.7913
# Epoch 31/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.1088 - accuracy: 0.9646 - precision: 0.9709 - recall: 0.9577 - val_loss: 0.9441 - val_accuracy: 0.8102 - val_precision: 0.8265 - val_recall: 0.8046
# Epoch 32/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.1043 - accuracy: 0.9652 - precision: 0.9711 - recall: 0.9607 - val_loss: 0.9740 - val_accuracy: 0.8178 - val_precision: 0.8288 - val_recall: 0.8083
# Epoch 33/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.0929 - accuracy: 0.9691 - precision: 0.9740 - recall: 0.9634 - val_loss: 0.8874 - val_accuracy: 0.8140 - val_precision: 0.8259 - val_recall: 0.8102
# Epoch 34/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.0967 - accuracy: 0.9666 - precision: 0.9724 - recall: 0.9618 - val_loss: 0.8868 - val_accuracy: 0.8140 - val_precision: 0.8304 - val_recall: 0.8083
# Epoch 35/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.0735 - accuracy: 0.9755 - precision: 0.9789 - recall: 0.9716 - val_loss: 1.0034 - val_accuracy: 0.8197 - val_precision: 0.8379 - val_recall: 0.8140
# Epoch 36/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.0949 - accuracy: 0.9689 - precision: 0.9727 - recall: 0.9655 - val_loss: 0.9413 - val_accuracy: 0.8159 - val_precision: 0.8346 - val_recall: 0.8046
# Epoch 37/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.0866 - accuracy: 0.9739 - precision: 0.9775 - recall: 0.9712 - val_loss: 0.9187 - val_accuracy: 0.8197 - val_precision: 0.8366 - val_recall: 0.8065
# Epoch 38/200
# 175/175 [==============================] - 25s 141ms/step - loss: 0.0772 - accuracy: 0.9752 - precision: 0.9793 - recall: 0.9716 - val_loss: 1.0986 - val_accuracy: 0.8065 - val_precision: 0.8147 - val_recall: 0.8008
# Epoch 39/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.0734 - accuracy: 0.9754 - precision: 0.9774 - recall: 0.9718 - val_loss: 1.0311 - val_accuracy: 0.8140 - val_precision: 0.8249 - val_recall: 0.8046
# Epoch 40/200
# 175/175 [==============================] - 25s 141ms/step - loss: 0.0855 - accuracy: 0.9734 - precision: 0.9773 - recall: 0.9684 - val_loss: 0.9084 - val_accuracy: 0.8197 - val_precision: 0.8320 - val_recall: 0.8083
# Epoch 41/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.0717 - accuracy: 0.9746 - precision: 0.9784 - recall: 0.9725 - val_loss: 0.9698 - val_accuracy: 0.8083 - val_precision: 0.8330 - val_recall: 0.8046
# Epoch 42/200
# 175/175 [==============================] - 25s 141ms/step - loss: 0.0601 - accuracy: 0.9816 - precision: 0.9844 - recall: 0.9793 - val_loss: 0.9076 - val_accuracy: 0.8102 - val_precision: 0.8242 - val_recall: 0.8008
# Epoch 43/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.0556 - accuracy: 0.9827 - precision: 0.9840 - recall: 0.9800 - val_loss: 0.9579 - val_accuracy: 0.8387 - val_precision: 0.8544 - val_recall: 0.8349
# Epoch 44/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.0602 - accuracy: 0.9820 - precision: 0.9841 - recall: 0.9805 - val_loss: 0.9488 - val_accuracy: 0.8121 - val_precision: 0.8356 - val_recall: 0.8102
# Epoch 45/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.0619 - accuracy: 0.9787 - precision: 0.9810 - recall: 0.9761 - val_loss: 1.3564 - val_accuracy: 0.8083 - val_precision: 0.8205 - val_recall: 0.8065
# Epoch 46/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.0615 - accuracy: 0.9796 - precision: 0.9821 - recall: 0.9786 - val_loss: 0.9373 - val_accuracy: 0.8311 - val_precision: 0.8418 - val_recall: 0.8178
# Epoch 47/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0624 - accuracy: 0.9829 - precision: 0.9846 - recall: 0.9804 - val_loss: 0.9077 - val_accuracy: 0.8425 - val_precision: 0.8591 - val_recall: 0.8330
# Epoch 48/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0465 - accuracy: 0.9852 - precision: 0.9878 - recall: 0.9836 - val_loss: 0.9829 - val_accuracy: 0.8292 - val_precision: 0.8493 - val_recall: 0.8235
# Epoch 49/200
# 175/175 [==============================] - 25s 145ms/step - loss: 0.0474 - accuracy: 0.9854 - precision: 0.9866 - recall: 0.9836 - val_loss: 1.2062 - val_accuracy: 0.8159 - val_precision: 0.8259 - val_recall: 0.8102
# Epoch 50/200
# 175/175 [==============================] - 25s 145ms/step - loss: 0.0433 - accuracy: 0.9868 - precision: 0.9876 - recall: 0.9850 - val_loss: 1.0877 - val_accuracy: 0.8387 - val_precision: 0.8511 - val_recall: 0.8349
# Epoch 51/200
# 175/175 [==============================] - 25s 145ms/step - loss: 0.0419 - accuracy: 0.9862 - precision: 0.9871 - recall: 0.9846 - val_loss: 1.1536 - val_accuracy: 0.8121 - val_precision: 0.8304 - val_recall: 0.8083
# Epoch 52/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0569 - accuracy: 0.9802 - precision: 0.9824 - recall: 0.9786 - val_loss: 1.3213 - val_accuracy: 0.8083 - val_precision: 0.8185 - val_recall: 0.8046
# Epoch 53/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0396 - accuracy: 0.9884 - precision: 0.9898 - recall: 0.9845 - val_loss: 1.0149 - val_accuracy: 0.8330 - val_precision: 0.8436 - val_recall: 0.8292
# Epoch 54/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0424 - accuracy: 0.9862 - precision: 0.9876 - recall: 0.9843 - val_loss: 1.0584 - val_accuracy: 0.8463 - val_precision: 0.8552 - val_recall: 0.8406
# Epoch 55/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0400 - accuracy: 0.9866 - precision: 0.9880 - recall: 0.9861 - val_loss: 1.1427 - val_accuracy: 0.8197 - val_precision: 0.8337 - val_recall: 0.8178
# Epoch 56/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0502 - accuracy: 0.9857 - precision: 0.9880 - recall: 0.9846 - val_loss: 1.3452 - val_accuracy: 0.8046 - val_precision: 0.8166 - val_recall: 0.8027
# Epoch 57/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.0595 - accuracy: 0.9814 - precision: 0.9826 - recall: 0.9795 - val_loss: 0.9735 - val_accuracy: 0.8330 - val_precision: 0.8436 - val_recall: 0.8292
# Epoch 58/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.0418 - accuracy: 0.9854 - precision: 0.9866 - recall: 0.9843 - val_loss: 1.1820 - val_accuracy: 0.8273 - val_precision: 0.8327 - val_recall: 0.8216
# Epoch 59/200
# 175/175 [==============================] - 25s 142ms/step - loss: 0.0440 - accuracy: 0.9845 - precision: 0.9860 - recall: 0.9836 - val_loss: 0.9355 - val_accuracy: 0.8235 - val_precision: 0.8362 - val_recall: 0.8235
# Epoch 60/200
# 175/175 [==============================] - 25s 143ms/step - loss: 0.0392 - accuracy: 0.9880 - precision: 0.9898 - recall: 0.9864 - val_loss: 1.0726 - val_accuracy: 0.8444 - val_precision: 0.8484 - val_recall: 0.8387
# Epoch 61/200
# 175/175 [==============================] - 25s 141ms/step - loss: 0.0344 - accuracy: 0.9893 - precision: 0.9903 - recall: 0.9873 - val_loss: 1.1090 - val_accuracy: 0.7989 - val_precision: 0.8038 - val_recall: 0.7932
# Epoch 62/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0327 - accuracy: 0.9882 - precision: 0.9894 - recall: 0.9870 - val_loss: 1.1490 - val_accuracy: 0.8406 - val_precision: 0.8494 - val_recall: 0.8349
# Epoch 63/200
# 175/175 [==============================] - 25s 144ms/step - loss: 0.0277 - accuracy: 0.9909 - precision: 0.9919 - recall: 0.9896 - val_loss: 1.2507 - val_accuracy: 0.8349 - val_precision: 0.8401 - val_recall: 0.8273
# Epoch 64/200
# 175/175 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9912 - precision: 0.9921 - recall: 0.9898Restoring model weights from the end of the best epoch: 54.
# 175/175 [==============================] - 25s 145ms/step - loss: 0.0273 - accuracy: 0.9912 - precision: 0.9921 - recall: 0.9898 - val_loss: 1.3958 - val_accuracy: 0.7970 - val_precision: 0.8000 - val_recall: 0.7894
# Epoch 64: early stopping

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(tl_history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(tl_history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
tl_model.save('Vgg19/Tuned_13layers_lowerlearning')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.

# %%
# Test the model
tl_model = tfk.models.load_model("Vgg19/Tuned_13layers_lowerlearning")
model_test_metrics = tl_model.evaluate(test_gen, return_dict=True)

print()
print("Test metrics")
print(model_test_metrics)
# Out:
# 12/12 [==============================] - 224s 20s/step - loss: 1.1496 - accuracy: 0.8089 - precision: 0.8106 - recall: 0.8061
#
# Test metrics
# {'loss': 1.1495860815048218, 'accuracy': 0.8088642954826355, 'precision': 0.8105849623680115, 'recall': 0.8060941696166992}

# %%
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

predictions = tl_model.predict_generator(test_gen, steps=224)
predicted_classes = np.argmax(predictions, axis=-1)

# Compute the confusion matrix
cm = (confusion_matrix(test_gen.classes, predicted_classes))

# Compute the classification metrics
accuracy = accuracy_score(test_gen.classes, predicted_classes)
precision = precision_score(test_gen.classes, predicted_classes, average='macro')
recall = recall_score(test_gen.classes, predicted_classes, average='macro')
f1 = f1_score(test_gen.classes, predicted_classes, average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   """
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 224 batches). You may need to use the repeat() function when building your dataset.
# Accuracy: 0.8089
# Precision: 0.794
# Recall: 0.7841
# F1: 0.786
