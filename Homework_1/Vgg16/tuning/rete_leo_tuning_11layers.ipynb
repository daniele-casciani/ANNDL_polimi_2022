# %%
# mount gdrive

from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/ANDL/Homework_1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/ANDL/Homework_1

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.optimizers import adam_v2

import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow.keras as tfk
import random
import os
import tensorflow as tf
from PIL import Image

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
# Dataset folders 
dataset_dir = 'atMost700'
training_dir = os.path.join(dataset_dir, 'train')
validation_dir = os.path.join(dataset_dir, 'val')
test_dir = os.path.join(dataset_dir, 'test')

labels = ['Species1','Species2','Species3','Species4','Species5','Species6','Species7','Species8',]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
category_names = sorted(os.listdir(training_dir))
nb_categories = len(category_names)
img_pr_cat = []
for category in category_names:
    folder = training_dir + '/' + category
    img_pr_cat.append(len(os.listdir(folder)))
sns.barplot(y=category_names, x=img_pr_cat).set_title("Number of training images per category:")
# Out:
# Text(0.5, 1.0, 'Number of training images per category:')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import array_to_img, img_to_array, load_img

# Create an instance of ImageDataGenerator with Data Augmentation
aug_train_data_gen = ImageDataGenerator(#rotation_range=180,
                                        height_shift_range=5,
                                        width_shift_range=5,
                                        #zoom_range=0.5,
                                        horizontal_flip=True,
                                        vertical_flip=True, 
                                        #fill_mode='nearest',
                                        preprocessing_function = preprocess_input,
                                        # rescale=1/255. not on vgg16
                                        ) 
valid_data_gen = ImageDataGenerator(#rescale=1/255.,
                                    preprocessing_function = preprocess_input)
test_data_gen = ImageDataGenerator(#rescale=1/255.,
                                   preprocessing_function = preprocess_input)

# %%
# Obtain a data generator with the 'ImageDataGenerator.flow_from_directory' method
aug_train_gen = aug_train_data_gen.flow_from_directory(directory=training_dir,
                                                       target_size=(96,96),
                                                       color_mode='rgb',
                                                       classes=None, # can be set to labels
                                                       class_mode='categorical',
                                                       batch_size=32,
                                                       shuffle=True,
                                                       seed=seed)

valid_gen = valid_data_gen.flow_from_directory(directory=validation_dir,
                                               target_size=(96,96),
                                               color_mode='rgb',
                                               classes=None, # can be set to labels
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=True,
                                               seed=seed)
test_gen = test_data_gen.flow_from_directory(directory=test_dir,
                                             target_size=(96,96),
                                             color_mode='rgb',
                                             classes=None, # can be set to labels
                                             class_mode='categorical',
                                             batch_size=32,
                                             shuffle=False,
                                             seed=seed)
# Out:
# Found 5600 images belonging to 8 classes.
# Found 527 images belonging to 8 classes.
# Found 361 images belonging to 8 classes.

# %%
def get_next_batch(generator):
  batch = next(generator)

  image = batch[0]
  target = batch[1]

  print("(Input) image shape:", image.shape)
  print("Target shape:",target.shape)

  # Visualize only the first sample
  image = image[0]
  target = target[0]
  target_idx = np.argmax(target)
  print()
  print("Categorical label:", target)
  print("Label:", target_idx)
  print("Class name:", labels[target_idx])
  fig = plt.figure(figsize=(6, 4))
  plt.imshow(np.uint8(image))

  return batch

# %%
# Get a sample from dataset and show info
_ = get_next_batch(aug_train_gen)
# Out:
# (Input) image shape: (32, 96, 96, 3)
# Target shape: (32, 8)
#
# Categorical label: [0. 0. 0. 0. 0. 0. 1. 0.]
# Label: 6
# Class name: Species7

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name):

  exps_dir = os.path.join('data_augmentation_experiments')
  if not os.path.exists(exps_dir):
      os.makedirs(exps_dir)

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=False, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
  callbacks.append(ckpt_callback)

  # Visualize Learning on Tensorboard
  # ---------------------------------
  tb_dir = os.path.join(exp_dir, 'tb_logs')
  if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
      
  # By default shows losses and metrics for both training and validation
  tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, 
                                               profile_batch=0,
                                               histogram_freq=1)  # if > 0 (epochs) shows weights histograms
  callbacks.append(tb_callback)

  # Early Stopping
  # --------------
  es_callback  = tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True)
  callbacks.append(es_callback)

  return callbacks

# %%
# Download and plot the VGG16 model
supernet = tfk.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(96,96,3)
)
supernet.summary()
tfk.utils.plot_model(supernet)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
input_shape = (96, 96, 3)
epochs = 200

# %%
import tensorflow.keras.layers as tfkl

# Use the supernet as feature extractor
supernet.trainable = False

inputs = tfk.Input(shape=(96,96,3))
# No resize
#x = tfkl.Resizing(64, 64, interpolation="bicubic")(inputs)
x = supernet(inputs)
x = tfkl.Flatten(name='Flattening')(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
x = tfkl.Dense(
    256, 
    activation='relu',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
output_layer = tfkl.Dense(units=8, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='Output')(x)



# Connect input and output through the Model class
tl_model = tfk.Model(inputs=inputs, outputs=output_layer, name='model')

# Compile the model
tl_model.compile(loss='categorical_crossentropy', optimizer=tfk.optimizers.Adam(), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 15,896,648
# Trainable params: 1,181,960
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   layer.trainable = False

for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 False
# 18 block5_pool False

# %%
# Train the model
tl_callbacks = create_folders_and_callbacks(model_name = 'transfer_learning')

# Train the model
tl_history = tl_model.fit(
    x = aug_train_gen,
    epochs = epochs,
    validation_data = valid_gen,
    callbacks = tl_callbacks,
    #class_weight=class_weight
).history
# Out:
# Epoch 1/200
# 175/175 [==============================] - ETA: 0s - loss: 3.0095 - accuracy: 0.4148 - precision: 0.4724 - recall: 0.3121
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 893s 5s/step - loss: 3.0095 - accuracy: 0.4148 - precision: 0.4724 - recall: 0.3121 - val_loss: 1.2939 - val_accuracy: 0.5028 - val_precision: 0.7440 - val_recall: 0.2922
# Epoch 2/200
# 175/175 [==============================] - ETA: 0s - loss: 1.3675 - accuracy: 0.5163 - precision: 0.6387 - recall: 0.3675
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 29s 163ms/step - loss: 1.3675 - accuracy: 0.5163 - precision: 0.6387 - recall: 0.3675 - val_loss: 1.1922 - val_accuracy: 0.5218 - val_precision: 0.6973 - val_recall: 0.3454
# Epoch 3/200
# 175/175 [==============================] - ETA: 0s - loss: 1.2055 - accuracy: 0.5627 - precision: 0.6892 - recall: 0.4254
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 28s 159ms/step - loss: 1.2055 - accuracy: 0.5627 - precision: 0.6892 - recall: 0.4254 - val_loss: 1.1086 - val_accuracy: 0.5806 - val_precision: 0.7668 - val_recall: 0.4118
# Epoch 4/200
# 175/175 [==============================] - ETA: 0s - loss: 1.1337 - accuracy: 0.5973 - precision: 0.7120 - recall: 0.4579
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 28s 158ms/step - loss: 1.1337 - accuracy: 0.5973 - precision: 0.7120 - recall: 0.4579 - val_loss: 1.0899 - val_accuracy: 0.5787 - val_precision: 0.7054 - val_recall: 0.4497
# Epoch 5/200
# 175/175 [==============================] - ETA: 0s - loss: 1.0617 - accuracy: 0.6152 - precision: 0.7343 - recall: 0.4920
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 29s 167ms/step - loss: 1.0617 - accuracy: 0.6152 - precision: 0.7343 - recall: 0.4920 - val_loss: 1.0385 - val_accuracy: 0.5958 - val_precision: 0.7284 - val_recall: 0.4630
# Epoch 6/200
# 175/175 [==============================] - ETA: 0s - loss: 0.9853 - accuracy: 0.6395 - precision: 0.7468 - recall: 0.5304
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 28s 160ms/step - loss: 0.9853 - accuracy: 0.6395 - precision: 0.7468 - recall: 0.5304 - val_loss: 1.0230 - val_accuracy: 0.6072 - val_precision: 0.7018 - val_recall: 0.5047
# Epoch 7/200
# 175/175 [==============================] - ETA: 0s - loss: 0.9715 - accuracy: 0.6502 - precision: 0.7522 - recall: 0.5377
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 27s 157ms/step - loss: 0.9715 - accuracy: 0.6502 - precision: 0.7522 - recall: 0.5377 - val_loss: 0.9980 - val_accuracy: 0.6053 - val_precision: 0.7451 - val_recall: 0.5047
# Epoch 8/200
# 175/175 [==============================] - ETA: 0s - loss: 0.9361 - accuracy: 0
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 28s 158ms/step - loss: 0.6962 - accuracy: 0.7518 - precision: 0.8199 - recall: 0.6770 - val_loss: 0.9697 - val_accuracy: 0.6414 - val_precision: 0.7418 - val_recall: 0.5560

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(tl_history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(tl_history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
tl_model.save('Vgg16/FineFineTuning_v1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.

# %%
tl_model = tfk.models.load_model('Vgg16/FineFineTuning_v1')
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 15,896,648
# Trainable params: 1,181,960
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
tl_model.get_layer('vgg16').trainable = True
for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 True
# 1 block1_conv1 True
# 2 block1_conv2 True
# 3 block1_pool True
# 4 block2_conv1 True
# 5 block2_conv2 True
# 6 block2_pool True
# 7 block3_conv1 True
# 8 block3_conv2 True
# 9 block3_conv3 True
# 10 block3_pool True
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool True
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
for i, layer in enumerate(tl_model.get_layer('vgg16').layers[:11]):
  layer.trainable=False
for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
tl_model.summary()
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool True
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 15,896,648
# Trainable params: 14,161,160
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
tl_model.compile(loss='categorical_crossentropy', optimizer=tfk.optimizers.Adam(1e-4), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
# Fine-tune the model
tl_history = tl_model.fit(
    x = aug_train_gen ,
    batch_size = 32,
    epochs = 200,
    validation_data = valid_gen,
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, verbose=2 , restore_best_weights=True)],
    #class_weight = class_weight
).history
# Out:
# Epoch 1/200
# 175/175 [==============================] - 27s 140ms/step - loss: 1.3522 - accuracy: 0.4991 - precision_1: 0.6319 - recall_1: 0.3182 - val_loss: 1.0341 - val_accuracy: 0.6490 - val_precision_1: 0.8007 - val_recall_1: 0.4497
# Epoch 2/200
# 175/175 [==============================] - 24s 139ms/step - loss: 0.9682 - accuracy: 0.6489 - precision_1: 0.7704 - recall_1: 0.5093 - val_loss: 0.8714 - val_accuracy: 0.6831 - val_precision_1: 0.7769 - val_recall_1: 0.5750
# Epoch 3/200
# 175/175 [==============================] - 24s 135ms/step - loss: 0.7784 - accuracy: 0.7236 - precision_1: 0.8137 - recall_1: 0.6152 - val_loss: 0.8979 - val_accuracy: 0.6926 - val_precision_1: 0.7903 - val_recall_1: 0.5579
# Epoch 4/200
# 175/175 [==============================] - 24s 135ms/step - loss: 0.6554 - accuracy: 0.7707 - precision_1: 0.8401 - recall_1: 0.6861 - val_loss: 0.8345 - val_accuracy: 0.7059 - val_precision_1: 0.8055 - val_recall_1: 0.6129
# Epoch 5/200
# 175/175 [==============================] - 24s 136ms/step - loss: 0.5656 - accuracy: 0.8096 - precision_1: 0.8691 - recall_1: 0.7420 - val_loss: 0.7654 - val_accuracy: 0.7457 - val_precision_1: 0.8154 - val_recall_1: 0.7040
# Epoch 6/200
# 175/175 [==============================] - 24s 136ms/step - loss: 0.5344 - accuracy: 0.8148 - precision_1: 0.8648 - recall_1: 0.7550 - val_loss: 0.7492 - val_accuracy: 0.7704 - val_precision_1: 0.8126 - val_recall_1: 0.7324
# Epoch 7/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.4254 - accuracy: 0.8584 - precision_1: 0.8949 - recall_1: 0.8163 - val_loss: 0.7016 - val_accuracy: 0.7685 - val_precision_1: 0.8330 - val_recall_1: 0.7097
# Epoch 8/200
# 175/175 [==============================] - 23s 134ms/step - loss: 0.3945 - accuracy: 0.8675 - precision_1: 0.9031 - recall_1: 0.8289 - val_loss: 0.7134 - val_accuracy: 0.7704 - val_precision_1: 0.8214 - val_recall_1: 0.7154
# Epoch 9/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.3356 - accuracy: 0.8902 - precision_1: 0.9142 - recall_1: 0.8598 - val_loss: 0.8781 - val_accuracy: 0.7362 - val_precision_1: 0.7812 - val_recall_1: 0.7116
# Epoch 10/200
# 175/175 [==============================] - 24s 135ms/step - loss: 0.3008 - accuracy: 0.9064 - precision_1: 0.9287 - recall_1: 0.8809 - val_loss: 0.7135 - val_accuracy: 0.7780 - val_precision_1: 0.8163 - val_recall_1: 0.7419
# Epoch 11/200
# 175/175 [==============================] - 23s 134ms/step - loss: 0.2840 - accuracy: 0.9089 - precision_1: 0.9313 - recall_1: 0.8866 - val_loss: 0.7681 - val_accuracy: 0.7723 - val_precision_1: 0.8294 - val_recall_1: 0.7287
# Epoch 12/200
# 175/175 [==============================] - 24s 136ms/step - loss: 0.2995 - accuracy: 0.9102 - precision_1: 0.9369 - recall_1: 0.8859 - val_loss: 0.6780 - val_accuracy: 0.8235 - val_precision_1: 0.8427 - val_recall_1: 0.7932
# Epoch 13/200
# 175/175 [==============================] - 25s 140ms/step - loss: 0.2218 - accuracy: 0.9300 - precision_1: 0.9477 - recall_1: 0.9121 - val_loss: 0.6973 - val_accuracy: 0.8273 - val_precision_1: 0.8429 - val_recall_1: 0.8046
# Epoch 14/200
# 175/175 [==============================] - 24s 134ms/step - loss: 0.2190 - accuracy: 0.9357 - precision_1: 0.9494 - recall_1: 0.9187 - val_loss: 0.9696 - val_accuracy: 0.7533 - val_precision_1: 0.7830 - val_recall_1: 0.7324
# Epoch 15/200
# 175/175 [==============================] - 24s 135ms/step - loss: 0.2284 - accuracy: 0.9354 - precision_1: 0.9490 - recall_1: 0.9180 - val_loss: 0.6415 - val_accuracy: 0.8008 - val_precision_1: 0.8276 - val_recall_1: 0.7742
# Epoch 16/200
# 175/175 [==============================] - 24s 135ms/step - loss: 0.1974 - accuracy: 0.9429 - precision_1: 0.9581 - recall_1: 0.9318 - val_loss: 0.7753 - val_accuracy: 0.8083 - val_precision_1: 0.8340 - val_recall_1: 0.7818
# Epoch 17/200
# 175/175 [==============================] - 24s 134ms/step - loss: 0.1915 - accuracy: 0.9404 - precision_1: 0.9541 - recall_1: 0.9277 - val_loss: 0.8543 - val_accuracy: 0.8216 - val_precision_1: 0.8340 - val_recall_1: 0.8008
# Epoch 18/200
# 175/175 [==============================] - 24s 136ms/step - loss: 0.1322 - accuracy: 0.9571 - precision_1: 0.9659 - recall_1: 0.9513 - val_loss: 0.6940 - val_accuracy: 0.8197 - val_precision_1: 0.8444 - val_recall_1: 0.7932
# Epoch 19/200
# 175/175 [==============================] - 23s 134ms/step - loss: 0.1085 - accuracy: 0.9657 - precision_1: 0.9718 - recall_1: 0.9607 - val_loss: 0.9887 - val_accuracy: 0.7951 - val_precision_1: 0.8231 - val_recall_1: 0.7856
# Epoch 20/200
# 175/175 [==============================] - 23s 134ms/step - loss: 0.1527 - accuracy: 0.9561 - precision_1: 0.9630 - recall_1: 0.9473 - val_loss: 0.6194 - val_accuracy: 0.8444 - val_precision_1: 0.8743 - val_recall_1: 0.8311
# Epoch 21/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.1262 - accuracy: 0.9620 - precision_1: 0.9662 - recall_1: 0.9546 - val_loss: 1.0034 - val_accuracy: 0.7951 - val_precision_1: 0.8090 - val_recall_1: 0.7875
# Epoch 22/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.0830 - accuracy: 0.9729 - precision_1: 0.9776 - recall_1: 0.9671 - val_loss: 0.8579 - val_accuracy: 0.8330 - val_precision_1: 0.8571 - val_recall_1: 0.8197
# Epoch 23/200
# 175/175 [==============================] - 23s 134ms/step - loss: 0.1341 - accuracy: 0.9630 - precision_1: 0.9716 - recall_1: 0.9532 - val_loss: 0.8480 - val_accuracy: 0.8121 - val_precision_1: 0.8323 - val_recall_1: 0.8008
# Epoch 24/200
# 175/175 [==============================] - 24s 138ms/step - loss: 0.1909 - accuracy: 0.9455 - precision_1: 0.9558 - recall_1: 0.9337 - val_loss: 0.7999 - val_accuracy: 0.8197 - val_precision_1: 0.8363 - val_recall_1: 0.8046
# Epoch 25/200
# 175/175 [==============================] - 24s 134ms/step - loss: 0.1626 - accuracy: 0.9532 - precision_1: 0.9633 - recall_1: 0.9414 - val_loss: 0.7344 - val_accuracy: 0.8102 - val_precision_1: 0.8357 - val_recall_1: 0.7913
# Epoch 26/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.0823 - accuracy: 0.9764 - precision_1: 0.9791 - recall_1: 0.9718 - val_loss: 1.1978 - val_accuracy: 0.7495 - val_precision_1: 0.7807 - val_recall_1: 0.7230
# Epoch 27/200
# 175/175 [==============================] - 23s 132ms/step - loss: 0.1270 - accuracy: 0.9636 - precision_1: 0.9716 - recall_1: 0.9580 - val_loss: 1.1455 - val_accuracy: 0.8273 - val_precision_1: 0.8478 - val_recall_1: 0.8140
# Epoch 28/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.0891 - accuracy: 0.9730 - precision_1: 0.9769 - recall_1: 0.9679 - val_loss: 0.7730 - val_accuracy: 0.8216 - val_precision_1: 0.8428 - val_recall_1: 0.8140
# Epoch 29/200
# 175/175 [==============================] - 23s 131ms/step - loss: 0.0661 - accuracy: 0.9809 - precision_1: 0.9835 - recall_1: 0.9787 - val_loss: 0.9082 - val_accuracy: 0.8140 - val_precision_1: 0.8327 - val_recall_1: 0.8027
# Epoch 30/200
# 175/175 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9680 - precision_1: 0.9719 - recall_1: 0.9641Restoring model weights from the end of the best epoch: 20.
# 175/175 [==============================] - 23s 133ms/step - loss: 0.1119 - accuracy: 0.9680 - precision_1: 0.9719 - recall_1: 0.9641 - val_loss: 0.8009 - val_accuracy: 0.8406 - val_precision_1: 0.8574 - val_recall_1: 0.8330
# Epoch 30: early stopping

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(tl_history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(tl_history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# %cd /gdrive/My Drive/ANDL/Homework_1
# Out:
# /gdrive/My Drive/ANDL/Homework_1

# %%
tl_model.save('Vgg16/layers_11')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.

# %%
tl_model.save('Vgg16/Tuned_v1_1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.

# %%
# Test the model
tl_model = tfk.models.load_model("Vgg16/Tuned_v1_1")
model_test_metrics = tl_model.evaluate(test_gen, return_dict=True)

print()
print("Test metrics")
print(model_test_metrics)
# Out:
# 12/12 [==============================] - 54s 5s/step - loss: 0.6098 - accuracy: 0.8338 - precision_1: 0.8576 - recall_1: 0.8172
#
# Test metrics
# {'loss': 0.609836220741272, 'accuracy': 0.8337950110435486, 'precision_1': 0.8575581312179565, 'recall_1': 0.81717449426651}

# %%
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

predictions = tl_model.predict_generator(test_gen, steps=224)
predicted_classes = np.argmax(predictions, axis=-1)

# Compute the confusion matrix
cm = (confusion_matrix(test_gen.classes, predicted_classes))

# Compute the classification metrics
accuracy = accuracy_score(test_gen.classes, predicted_classes)
precision = precision_score(test_gen.classes, predicted_classes, average='macro')
recall = recall_score(test_gen.classes, predicted_classes, average='macro')
f1 = f1_score(test_gen.classes, predicted_classes, average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   """
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 224 batches). You may need to use the repeat() function when building your dataset.
# Accuracy: 0.8338
# Precision: 0.8196
# Recall: 0.8029
# F1: 0.8078
