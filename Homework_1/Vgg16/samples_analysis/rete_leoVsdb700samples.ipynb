#   inflating: atMost700/val/Species8/00311.jpg
#   inflating: atMost700/val/Species8/00316.jpg
#   inflating: atMost700/val/Species8/00321.jpg
#   inflating: atMost700/val/Species8/00325.jpg
#   inflating: atMost700/val/Species8/00331.jpg
#   inflating: atMost700/val/Species8/00338.jpg
#   inflating: atMost700/val/Species8/00343.jpg
#   inflating: atMost700/val/Species8/00349.jpg
#   inflating: atMost700/val/Species8/00350.jpg
#   inflating: atMost700/val/Species8/00352.jpg
#   inflating: atMost700/val/Species8/00360.jpg
#   inflating: atMost700/val/Species8/00367.jpg
#   inflating: atMost700/val/Species8/00373.jpg
#   inflating: atMost700/val/Species8/00395.jpg
#   inflating: atMost700/val/Species8/00413.jpg
#   inflating: atMost700/val/Species8/00417.jpg
#   inflating: atMost700/val/Species8/00419.jpg
#   inflating: atMost700/val/Species8/00422.jpg
#   inflating: atMost700/val/Species8/00424.jpg
#   inflating: atMost700/val/Species8/00433.jpg
#   inflating: atMost700/val/Species8/00441.jpg
#   inflating: atMost700/val/Species8/00446.jpg
#   inflating: atMost700/val/Species8/00455.jpg
#   inflating: atMost700/val/Species8/00462.jpg
#   inflating: atMost700/val/Species8/00468.jpg
#   inflating: atMost700/val/Species8/00475.jpg
#   inflating: atMost700/val/Species8/00478.jpg
#   inflating: atMost700/val/Species8/00486.jpg
#   inflating: atMost700/val/Species8/00488.jpg
#   inflating: atMost700/val/Species8/00490.jpg
#   inflating: atMost700/val/Species8/00502.jpg
#   inflating: atMost700/val/Species8/00507.jpg

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.optimizers import adam_v2

import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow.keras as tfk
import random
import os
import tensorflow as tf
from PIL import Image

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
# Dataset folders 
dataset_dir = 'atMost700'
training_dir = os.path.join(dataset_dir, 'train')
validation_dir = os.path.join(dataset_dir, 'val')
test_dir = os.path.join(dataset_dir, 'test')

labels = ['Species1','Species2','Species3','Species4','Species5','Species6','Species7','Species8',]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
category_names = sorted(os.listdir(training_dir))
nb_categories = len(category_names)
img_pr_cat = []
for category in category_names:
    folder = training_dir + '/' + category
    img_pr_cat.append(len(os.listdir(folder)))
sns.barplot(y=category_names, x=img_pr_cat).set_title("Number of training images per category:")
# Out:
# Text(0.5, 1.0, 'Number of training images per category:')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import array_to_img, img_to_array, load_img

# Create an instance of ImageDataGenerator with Data Augmentation
aug_train_data_gen = ImageDataGenerator(#rotation_range=180,
                                        height_shift_range=5,
                                        width_shift_range=5,
                                        #zoom_range=0.5,
                                        horizontal_flip=True,
                                        vertical_flip=True, 
                                        #fill_mode='nearest',
                                        preprocessing_function = preprocess_input,
                                        # rescale=1/255. not on vgg16
                                        ) 
valid_data_gen = ImageDataGenerator(#rescale=1/255.,
                                    preprocessing_function = preprocess_input)
test_data_gen = ImageDataGenerator(#rescale=1/255.,
                                   preprocessing_function = preprocess_input)

# %%
# Obtain a data generator with the 'ImageDataGenerator.flow_from_directory' method
aug_train_gen = aug_train_data_gen.flow_from_directory(directory=training_dir,
                                                       target_size=(96,96),
                                                       color_mode='rgb',
                                                       classes=None, # can be set to labels
                                                       class_mode='categorical',
                                                       batch_size=32,
                                                       shuffle=True,
                                                       seed=seed)

valid_gen = valid_data_gen.flow_from_directory(directory=validation_dir,
                                               target_size=(96,96),
                                               color_mode='rgb',
                                               classes=None, # can be set to labels
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=True,
                                               seed=seed)
test_gen = test_data_gen.flow_from_directory(directory=test_dir,
                                             target_size=(96,96),
                                             color_mode='rgb',
                                             classes=None, # can be set to labels
                                             class_mode='categorical',
                                             batch_size=32,
                                             shuffle=False,
                                             seed=seed)
# Out:
# Found 5600 images belonging to 8 classes.
# Found 527 images belonging to 8 classes.
# Found 361 images belonging to 8 classes.

# %%
def get_next_batch(generator):
  batch = next(generator)

  image = batch[0]
  target = batch[1]

  print("(Input) image shape:", image.shape)
  print("Target shape:",target.shape)

  # Visualize only the first sample
  image = image[0]
  target = target[0]
  target_idx = np.argmax(target)
  print()
  print("Categorical label:", target)
  print("Label:", target_idx)
  print("Class name:", labels[target_idx])
  fig = plt.figure(figsize=(6, 4))
  plt.imshow(np.uint8(image))

  return batch

# %%
# Get a sample from dataset and show info
_ = get_next_batch(aug_train_gen)
# Out:
# (Input) image shape: (32, 96, 96, 3)
# Target shape: (32, 8)
#
# Categorical label: [0. 0. 0. 0. 0. 0. 1. 0.]
# Label: 6
# Class name: Species7

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name):

  exps_dir = os.path.join('data_augmentation_experiments')
  if not os.path.exists(exps_dir):
      os.makedirs(exps_dir)

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=False, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
  callbacks.append(ckpt_callback)

  # Visualize Learning on Tensorboard
  # ---------------------------------
  tb_dir = os.path.join(exp_dir, 'tb_logs')
  if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
      
  # By default shows losses and metrics for both training and validation
  tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, 
                                               profile_batch=0,
                                               histogram_freq=1)  # if > 0 (epochs) shows weights histograms
  callbacks.append(tb_callback)

  # Early Stopping
  # --------------
  es_callback  = tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True)
  callbacks.append(es_callback)

  return callbacks

# %%
# Download and plot the VGG16 model
supernet = tfk.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(96,96,3)
)
supernet.summary()
tfk.utils.plot_model(supernet)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
input_shape = (96, 96, 3)
epochs = 200

# %%
import tensorflow.keras.layers as tfkl

# Use the supernet as feature extractor
supernet.trainable = False

inputs = tfk.Input(shape=(96,96,3))
# No resize
#x = tfkl.Resizing(64, 64, interpolation="bicubic")(inputs)
x = supernet(inputs)
x = tfkl.Flatten(name='Flattening')(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
x = tfkl.Dense(
    256, 
    activation='relu',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)
x = tfkl.Dropout(0.3, seed=seed)(x)
output_layer = tfkl.Dense(units=8, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='Output')(x)



# Connect input and output through the Model class
tl_model = tfk.Model(inputs=inputs, outputs=output_layer, name='model')

# Compile the model
tl_model.compile(loss='categorical_crossentropy', optimizer=tfk.optimizers.Adam(), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 15,896,648
# Trainable params: 1,181,960
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   layer.trainable = False

for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 False
# 18 block5_pool False

# %%
# Train the model
tl_callbacks = create_folders_and_callbacks(model_name = 'transfer_learning')

# Train the model
tl_history = tl_model.fit(
    x = aug_train_gen,
    epochs = epochs,
    validation_data = valid_gen,
    callbacks = tl_callbacks,
    #class_weight=class_weight
).history
# Out:
# Epoch 1/200
# 175/175 [==============================] - ETA: 0s - loss: 3.0095 - accuracy: 0.4148 - precision: 0.4724 - recall: 0.3121
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] -
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 28s 159ms/step - loss: 0.7658 - accuracy: 0.7259 - precision: 0.8060 - recall: 0.6514 - val_loss: 0.9506 - val_accuracy: 0.6205 - val_precision: 0.7380 - val_recall: 0.5560
# Epoch 20/200
# 175/175 [==============================] - ETA: 0s - loss: 0.7565 - accuracy: 0.7391 - precision: 0.8134 - recall: 0.6607
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 27s 156ms/step - loss: 0.7565 - accuracy: 0.7391 - precision: 0.8134 - recall: 0.6607 - val_loss: 0.9670 - val_accuracy: 0.6622 - val_precision: 0.7457 - val_recall: 0.5787
# Epoch 21/200
# 175/175 [==============================] - ETA: 0s - loss: 0.7371 - accuracy: 0.7309 - precision: 0.8118 - recall: 0.6539
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 28s 161ms/step - loss: 0.7371 - accuracy: 0.7309 - precision: 0.8118 - recall: 0.6539 - val_loss: 0.9556 - val_accuracy: 0.6509 - val_precision: 0.7720 - val_recall: 0.5332
# Epoch 22/200
# 175/175 [==============================] - ETA: 0s - loss: 0.7334 - accuracy: 0.7398 - precision: 0.8162 - recall: 0.6623
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 27s 156ms/step - loss: 0.7334 - accuracy: 0.7398 - precision: 0.8162 - recall: 0.6623 - val_loss: 0.9700 - val_accuracy: 0.6243 - val_precision: 0.7228 - val_recall: 0.5541
# Epoch 23/200
# 175/175 [==============================] - ETA: 0s - loss: 0.7210 - accuracy: 0.7391 - precision: 0.8153 - recall: 0.6730
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 28s 163ms/step - loss: 0.7210 - accuracy: 0.7391 - precision: 0.8153 - recall: 0.6730 - val_loss: 1.0188 - val_accuracy: 0.6509 - val_precision: 0.7474 - val_recall: 0.5503
# Epoch 24/200
# 175/175 [==============================] - ETA: 0s - loss: 0.7232 - accuracy: 0.7402 - precision: 0.8093 - recall: 0.6632
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 29s 166ms/step - loss: 0.7232 - accuracy: 0.7402 - precision: 0.8093 - recall: 0.6632 - val_loss: 0.9578 - val_accuracy: 0.6395 - val_precision: 0.7658 - val_recall: 0.5522
# Epoch 25/200
# 175/175 [==============================] - ETA: 0s - loss: 0.7113 - accuracy: 0.7454 - precision: 0.8172 - recall: 0.6696
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 175/175 [==============================] - 28s 162ms/step - loss: 0.7113 - accuracy: 0.7454 - precision: 0.8172 - recall: 0.6696 - val_loss: 0.9710 - val_accuracy: 0.6376 - val_precision: 0.7506 - val_recall: 0.5541

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(tl_history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(tl_history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
tl_model.save('Vgg16/FineFineTuning_v1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.

# %%
tl_model = tfk.models.load_model('Vgg16/FineFineTuning_v1')
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 15,896,648
# Trainable params: 1,181,960
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
tl_model.get_layer('vgg16').trainable = True
for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 True
# 1 block1_conv1 True
# 2 block1_conv2 True
# 3 block1_pool True
# 4 block2_conv1 True
# 5 block2_conv2 True
# 6 block2_pool True
# 7 block3_conv1 True
# 8 block3_conv2 True
# 9 block3_conv3 True
# 10 block3_pool True
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool True
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
for i, layer in enumerate(tl_model.get_layer('vgg16').layers[:15]):
  layer.trainable=False
for i, layer in enumerate(tl_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
tl_model.summary()
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  Flattening (Flatten)        (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 15,896,648
# Trainable params: 8,261,384
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
tl_model.compile(loss='categorical_crossentropy', optimizer=tfk.optimizers.Adam(1e-4), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
# Fine-tune the model
tl_history = tl_model.fit(
    x = aug_train_gen ,
    batch_size = 32,
    epochs = 200,
    validation_data = valid_gen,
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, verbose=2 , restore_best_weights=True)],
    #class_weight = class_weight
).history
# Out:
# Epoch 1/200
# 175/175 [==============================] - 27s 139ms/step - loss: 1.0082 - accuracy: 0.6427 - precision_1: 0.7336 - recall_1: 0.5439 - val_loss: 0.9516 - val_accuracy: 0.6395 - val_precision_1: 0.7286 - val_recall_1: 0.5503
# Epoch 2/200
# 175/175 [==============================] - 22s 128ms/step - loss: 0.8014 - accuracy: 0.7127 - precision_1: 0.7970 - recall_1: 0.6275 - val_loss: 0.9434 - val_accuracy: 0.6755 - val_precision_1: 0.7506 - val_recall_1: 0.5769
# Epoch 3/200
# 175/175 [==============================] - 23s 129ms/step - loss: 0.6791 - accuracy: 0.7621 - precision_1: 0.8287 - recall_1: 0.6886 - val_loss: 0.9022 - val_accuracy: 0.6926 - val_precision_1: 0.7710 - val_recall_1: 0.6262
# Epoch 4/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.6594 - accuracy: 0.7639 - precision_1: 0.8377 - recall_1: 0.6950 - val_loss: 0.8141 - val_accuracy: 0.6907 - val_precision_1: 0.7718 - val_recall_1: 0.6224
# Epoch 5/200
# 175/175 [==============================] - 22s 127ms/step - loss: 0.5349 - accuracy: 0.8084 - precision_1: 0.8628 - recall_1: 0.7470 - val_loss: 0.8193 - val_accuracy: 0.7343 - val_precision_1: 0.7965 - val_recall_1: 0.6907
# Epoch 6/200
# 175/175 [==============================] - 23s 129ms/step - loss: 0.4658 - accuracy: 0.8284 - precision_1: 0.8684 - recall_1: 0.7836 - val_loss: 0.7868 - val_accuracy: 0.7476 - val_precision_1: 0.8055 - val_recall_1: 0.6679
# Epoch 7/200
# 175/175 [==============================] - 23s 132ms/step - loss: 0.4444 - accuracy: 0.8482 - precision_1: 0.8885 - recall_1: 0.8036 - val_loss: 0.8474 - val_accuracy: 0.7533 - val_precision_1: 0.8075 - val_recall_1: 0.6926
# Epoch 8/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.4649 - accuracy: 0.8459 - precision_1: 0.8833 - recall_1: 0.7998 - val_loss: 0.8991 - val_accuracy: 0.7078 - val_precision_1: 0.7787 - val_recall_1: 0.6812
# Epoch 9/200
# 175/175 [==============================] - 22s 127ms/step - loss: 0.3748 - accuracy: 0.8712 - precision_1: 0.9027 - recall_1: 0.8370 - val_loss: 0.7392 - val_accuracy: 0.7552 - val_precision_1: 0.7979 - val_recall_1: 0.7192
# Epoch 10/200
# 175/175 [==============================] - 23s 132ms/step - loss: 0.3196 - accuracy: 0.8895 - precision_1: 0.9133 - recall_1: 0.8620 - val_loss: 0.7742 - val_accuracy: 0.7704 - val_precision_1: 0.8137 - val_recall_1: 0.7457
# Epoch 11/200
# 175/175 [==============================] - 23s 129ms/step - loss: 0.3044 - accuracy: 0.8971 - precision_1: 0.9234 - recall_1: 0.8720 - val_loss: 0.8336 - val_accuracy: 0.7837 - val_precision_1: 0.8105 - val_recall_1: 0.7628
# Epoch 12/200
# 175/175 [==============================] - 23s 130ms/step - loss: 0.2853 - accuracy: 0.9062 - precision_1: 0.9274 - recall_1: 0.8809 - val_loss: 0.8211 - val_accuracy: 0.7628 - val_precision_1: 0.7926 - val_recall_1: 0.7324
# Epoch 13/200
# 175/175 [==============================] - 23s 132ms/step - loss: 0.2679 - accuracy: 0.9118 - precision_1: 0.9301 - recall_1: 0.8939 - val_loss: 0.8548 - val_accuracy: 0.7552 - val_precision_1: 0.7926 - val_recall_1: 0.7324
# Epoch 14/200
# 175/175 [==============================] - 23s 129ms/step - loss: 0.2676 - accuracy: 0.9111 - precision_1: 0.9301 - recall_1: 0.8930 - val_loss: 0.7721 - val_accuracy: 0.7856 - val_precision_1: 0.8126 - val_recall_1: 0.7571
# Epoch 15/200
# 175/175 [==============================] - 23s 131ms/step - loss: 0.2245 - accuracy: 0.9261 - precision_1: 0.9407 - recall_1: 0.9095 - val_loss: 0.9049 - val_accuracy: 0.7837 - val_precision_1: 0.8102 - val_recall_1: 0.7533
# Epoch 16/200
# 175/175 [==============================] - 22s 127ms/step - loss: 0.2172 - accuracy: 0.9241 - precision_1: 0.9359 - recall_1: 0.9123 - val_loss: 0.8933 - val_accuracy: 0.7571 - val_precision_1: 0.7833 - val_recall_1: 0.7476
# Epoch 17/200
# 175/175 [==============================] - 23s 131ms/step - loss: 0.2117 - accuracy: 0.9300 - precision_1: 0.9422 - recall_1: 0.9166 - val_loss: 0.8157 - val_accuracy: 0.7894 - val_precision_1: 0.8111 - val_recall_1: 0.7742
# Epoch 18/200
# 175/175 [==============================] - 22s 128ms/step - loss: 0.2336 - accuracy: 0.9279 - precision_1: 0.9417 - recall_1: 0.9146 - val_loss: 0.9976 - val_accuracy: 0.7533 - val_precision_1: 0.7725 - val_recall_1: 0.7343
# Epoch 19/200
# 175/175 [==============================] - 24s 135ms/step - loss: 0.1835 - accuracy: 0.9361 - precision_1: 0.9465 - recall_1: 0.9252 - val_loss: 1.0573 - val_accuracy: 0.7666 - val_precision_1: 0.7884 - val_recall_1: 0.7495
# Epoch 20/200
# 175/175 [==============================] - 22s 128ms/step - loss: 0.1744 - accuracy: 0.9475 - precision_1: 0.9590 - recall_1: 0.9355 - val_loss: 0.9132 - val_accuracy: 0.7647 - val_precision_1: 0.7867 - val_recall_1: 0.7419
# Epoch 21/200
# 175/175 [==============================] - 24s 134ms/step - loss: 0.1855 - accuracy: 0.9393 - precision_1: 0.9481 - recall_1: 0.9304 - val_loss: 0.7726 - val_accuracy: 0.7989 - val_precision_1: 0.8158 - val_recall_1: 0.7818
# Epoch 22/200
# 175/175 [==============================] - 22s 127ms/step - loss: 0.1684 - accuracy: 0.9482 - precision_1: 0.9556 - recall_1: 0.9413 - val_loss: 0.7269 - val_accuracy: 0.8008 - val_precision_1: 0.8194 - val_recall_1: 0.7837
# Epoch 23/200
# 175/175 [==============================] - 23s 131ms/step - loss: 0.1485 - accuracy: 0.9532 - precision_1: 0.9599 - recall_1: 0.9448 - val_loss: 0.9177 - val_accuracy: 0.7856 - val_precision_1: 0.8031 - val_recall_1: 0.7742
# Epoch 24/200
# 175/175 [==============================] - 23s 129ms/step - loss: 0.1656 - accuracy: 0.9511 - precision_1: 0.9609 - recall_1: 0.9443 - val_loss: 0.9320 - val_accuracy: 0.7875 - val_precision_1: 0.8108 - val_recall_1: 0.7723
# Epoch 25/200
# 175/175 [==============================] - 23s 131ms/step - loss: 0.1304 - accuracy: 0.9591 - precision_1: 0.9668 - recall_1: 0.9521 - val_loss: 0.9787 - val_accuracy: 0.7856 - val_precision_1: 0.8067 - val_recall_1: 0.7761
# Epoch 26/200
# 175/175 [==============================] - 22s 127ms/step - loss: 0.1103 - accuracy: 0.9663 - precision_1: 0.9720 - recall_1: 0.9605 - val_loss: 1.0047 - val_accuracy: 0.7818 - val_precision_1: 0.7996 - val_recall_1: 0.7571
# Epoch 27/200
# 175/175 [==============================] - 22s 128ms/step - loss: 0.1495 - accuracy: 0.9564 - precision_1: 0.9635 - recall_1: 0.9470 - val_loss: 0.8192 - val_accuracy: 0.8159 - val_precision_1: 0.8416 - val_recall_1: 0.8065
# Epoch 28/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.1449 - accuracy: 0.9564 - precision_1: 0.9609 - recall_1: 0.9491 - val_loss: 0.9067 - val_accuracy: 0.8008 - val_precision_1: 0.8337 - val_recall_1: 0.7894
# Epoch 29/200
# 175/175 [==============================] - 22s 128ms/step - loss: 0.1233 - accuracy: 0.9659 - precision_1: 0.9720 - recall_1: 0.9620 - val_loss: 0.8855 - val_accuracy: 0.8140 - val_precision_1: 0.8281 - val_recall_1: 0.7951
# Epoch 30/200
# 175/175 [==============================] - 23s 132ms/step - loss: 0.1128 - accuracy: 0.9663 - precision_1: 0.9709 - recall_1: 0.9579 - val_loss: 1.0259 - val_accuracy: 0.7932 - val_precision_1: 0.8059 - val_recall_1: 0.7799
# Epoch 31/200
# 175/175 [==============================] - 22s 127ms/step - loss: 0.0950 - accuracy: 0.9723 - precision_1: 0.9761 - recall_1: 0.9696 - val_loss: 0.7905 - val_accuracy: 0.8254 - val_precision_1: 0.8353 - val_recall_1: 0.8178
# Epoch 32/200
# 175/175 [==============================] - 24s 135ms/step - loss: 0.1591 - accuracy: 0.9552 - precision_1: 0.9619 - recall_1: 0.9479 - val_loss: 0.8529 - val_accuracy: 0.8065 - val_precision_1: 0.8200 - val_recall_1: 0.7951
# Epoch 33/200
# 175/175 [==============================] - 22s 127ms/step - loss: 0.0984 - accuracy: 0.9716 - precision_1: 0.9757 - recall_1: 0.9673 - val_loss: 0.9282 - val_accuracy: 0.7989 - val_precision_1: 0.8240 - val_recall_1: 0.7818
# Epoch 34/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.0902 - accuracy: 0.9689 - precision_1: 0.9735 - recall_1: 0.9655 - val_loss: 0.8447 - val_accuracy: 0.8027 - val_precision_1: 0.8184 - val_recall_1: 0.7951
# Epoch 35/200
# 175/175 [==============================] - 22s 128ms/step - loss: 0.0954 - accuracy: 0.9729 - precision_1: 0.9765 - recall_1: 0.9702 - val_loss: 1.0924 - val_accuracy: 0.7989 - val_precision_1: 0.8198 - val_recall_1: 0.7856
# Epoch 36/200
# 175/175 [==============================] - 23s 131ms/step - loss: 0.0992 - accuracy: 0.9720 - precision_1: 0.9762 - recall_1: 0.9680 - val_loss: 1.1500 - val_accuracy: 0.7457 - val_precision_1: 0.7692 - val_recall_1: 0.7400
# Epoch 37/200
# 175/175 [==============================] - 22s 127ms/step - loss: 0.0847 - accuracy: 0.9739 - precision_1: 0.9766 - recall_1: 0.9705 - val_loss: 1.0173 - val_accuracy: 0.7856 - val_precision_1: 0.8158 - val_recall_1: 0.7818
# Epoch 38/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.0691 - accuracy: 0.9775 - precision_1: 0.9799 - recall_1: 0.9752 - val_loss: 1.1000 - val_accuracy: 0.7989 - val_precision_1: 0.8140 - val_recall_1: 0.7970
# Epoch 39/200
# 175/175 [==============================] - 23s 128ms/step - loss: 0.0697 - accuracy: 0.9800 - precision_1: 0.9821 - recall_1: 0.9775 - val_loss: 1.4713 - val_accuracy: 0.7856 - val_precision_1: 0.7946 - val_recall_1: 0.7780
# Epoch 40/200
# 175/175 [==============================] - 23s 133ms/step - loss: 0.0975 - accuracy: 0.9725 - precision_1: 0.9754 - recall_1: 0.9695 - val_loss: 1.1139 - val_accuracy: 0.8065 - val_precision_1: 0.8147 - val_recall_1: 0.8008
# Epoch 41/200
# 175/175 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9820 - precision_1: 0.9842 - recall_1: 0.9793Restoring model weights from the end of the best epoch: 31.
# 175/175 [==============================] - 22s 128ms/step - loss: 0.0750 - accuracy: 0.9820 - precision_1: 0.9842 - recall_1: 0.9793 - val_loss: 1.0649 - val_accuracy: 0.7875 - val_precision_1: 0.8043 - val_recall_1: 0.7723
# Epoch 41: early stopping

# %%
# Plot the training
plt.figure(figsize=(15,5))

plt.plot(tl_history['loss'],label = 'Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))

plt.plot(tl_history['accuracy'],label = 'Training Accuracy' , alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# %cd /gdrive/My Drive/ANDL/Homework_1
# Out:
# /gdrive/My Drive/ANDL/Homework_1

# %%
tl_model.save('Vgg16/Tuned_v1_1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.

# %%
# Test the model
tl_model = tfk.models.load_model("Vgg16/Tuned_v1_1")
model_test_metrics = tl_model.evaluate(test_gen, return_dict=True)

print()
print("Test metrics")
print(model_test_metrics)
# Out:
# 12/12 [==============================] - 1s 91ms/step - loss: 0.8713 - accuracy: 0.8393 - precision_1: 0.8479 - recall_1: 0.8338
#
# Test metrics
# {'loss': 0.8713129758834839, 'accuracy': 0.8393352031707764, 'precision_1': 0.8478873372077942, 'recall_1': 0.8337950110435486}

# %%
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

predictions = tl_model.predict_generator(test_gen, steps=224)
predicted_classes = np.argmax(predictions, axis=-1)

# Compute the confusion matrix
cm = (confusion_matrix(test_gen.classes, predicted_classes))

# Compute the classification metrics
accuracy = accuracy_score(test_gen.classes, predicted_classes)
precision = precision_score(test_gen.classes, predicted_classes, average='macro')
recall = recall_score(test_gen.classes, predicted_classes, average='macro')
f1 = f1_score(test_gen.classes, predicted_classes, average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   """
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 224 batches). You may need to use the repeat() function when building your dataset.
# Accuracy: 0.8393
# Precision: 0.8357
# Recall: 0.8178
# F1: 0.8228
